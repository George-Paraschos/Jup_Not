# %%
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import math
# %matplotlib inline
#radex values in erg/cm^2/s
#points = np.array([(1, 2.383*10**-7*10**-7*10**-26*4*math.pi*(338*10**6*3.086*10**18)**2/3.826/10**26), (2, 1.653*10**-6*10**-7*10**-26*4*math.pi*(338*10**6*3.086*10**18)**2/3.826/10**26), (3, 4.585*10**-6*10**-7*10**-26*4*math.pi*(338*10**6*3.086*10**18)**2/3.826/10**26),])
#y=Flux_Radex*10**-7(erg/s to Watt)*4piR^2/L_sun, R=338Mpc-->338*10**6*3.086*10**18cm


points = np.array([(1,47552), (2,50713), (3,336761)])
x = points[:,0]
y = points[:,1]
#z = np.polyfit(x, y, 3)
#f = np.poly1d(z)
#print(f)
#x_new = np.linspace(x[0], x[-1], 50)
#y_new = f(x_new)
#plt.plot(x,y,'o', x_new, y_new)
plt.semilogy(x,y,'o')
plt.xlabel('Upper J')
plt.ylabel('L/L_sun')
plt.title('CO SLED')
#plt.ylim(0,5*10**-19)
plt.xlim(0,3.5)
plt.savefig("SLED123.png")

# %%
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import math
# %matplotlib inline
#πειραματικές τιμές από mapping
y=[2493316.0560000003,16153759.9965,75279789.1965]
x=[1,2,3]
#plt.semilogy(x,y,'o')
plt.plot(x,y,'o')

plt.xlim(0,3.5)
plt.xlabel('Upper J')
plt.ylabel('L/L_sun')
plt.savefig('SLED_exp.png')
