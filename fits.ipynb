# %%
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
# %matplotlib inline

x=[
6000000000000000,
5714285714285714,
5442176870748299,
5183025591188856,
4936214848751291,
4701156998810753,
4.47729237981976E+015,
4264087980780728,
4061036172172121,
3867653497306782,
3.68347952124455E+015,
3.50807573451862E+015,
3341024509065355,
3181928103871766,
3030407717973111,
2886102588545820,
2.7486691319484E+015,
2617780125665142,
2.4931239292049E+015,
2.3744037420999E+015,
2261336897238002,
2153654187845716,
2.05109922651973E+015,
1.95342783478069E+015,
1.8604074616959E+015,
1771816630186571,
1687444409701496,
1.60708991400142E+015,
1.5305618228585E+015,
1.4576779265319E+015,
1.38826469193515E+015,
1.32215684946204E+015,
1.25919699948766E+015,
1.1992352376073E+015,
1.14212879772123E+015,
1.08774171211546E+015,
1.03594448772901E+015,
986613797837153,
939632188416337,
894887798491749,
852274093801666,
811689613144443,
773037726804232,
736226406480221,
701168006171639,
667779053496799,
635980050949332,
605695286618412,
576852653922297,
549383479925997,
523222361834283,
498307011270745,
474578105972139,
451979148544894,
430456331947518,
409958411378588,
390436582265322,
371844364062212,
354137489583059,
337273799602913,
321213142478965,
305917278551395,
291349789096567,
277475989615778,
264262847253122,
251678902145830,
239694192519838,
228280183352227,
217409698430692,
207056855648278,
197197005379313
]

y=[
2.74E-09,
1.72E-08,
9.73E-08,
5.02E-07,
2.37E-06,
1.03E-05,
4.09E-05,
1.51E-04,
5.19E-04,
1.66E-03,
4.97E-03,
1.39E-02,
3.68E-02,
9.18E-02,
2.16E-01,
4.84E-01,
1.03E+00,
2.09E+00,
4.06E+00,
7.55E+00,
1.35E+01,
2.31E+01,
3.81E+01,
6.08E+01,
9.37E+01,
1.40E+02,
2.02E+02,
2.85E+02,
3.89E+02,
5.18E+02,
6.73E+02,
8.52E+02,
1.06E+03,
1.28E+03,
1.52E+03,
1.77E+03,
2.02E+03,
2.27E+03,
2.50E+03,
2.71E+03,
2.90E+03,
3.05E+03,
3.17E+03,
3.25E+03,
3.29E+03,
3.30E+03,
3.26E+03,
3.19E+03,
3.09E+03,
2.97E+03,
2.83E+03,
2.67E+03,
2.50E+03,
2.32E+03,
2.14E+03,
1.96E+03,
1.78E+03,
1.61E+03,
1.45E+03,
1.30E+03,
1.16E+03,
1.03E+03,
9.08E+02,
7.99E+02,
7.00E+02,
6.11E+02,
5.31E+02,
4.61E+02,
3.99E+02,
3.44E+02,
2.96E+02
]


x1=np.linspace(0,6*10**15)
y1=np.power(x1,3)/np.exp((np.multiply(x1,7.3*10**-15))+1)*1.5*10**-50


#plt.plot(x,y,'o')
plt.plot(x1,y1,'*')
#plt.plot(x,y1,'o')
#plt.xlim(0,10**4)

# %%
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
# %matplotlib inline

x=[
353000000000,
231000000000,
150000000000,
90000000000,
36800000000,
36800000000,
32000000000,
31400000000,
31400000000,
22500000000,
22500000000,
22500000000,
22500000000,
22500000000,
22200000000,
22200000000,
22200000000,
15300000000,
15100000000,
15000000000,
15000000000,
15000000000,
15000000000,
15000000000,
15000000000,
15000000000,
11200000000,
10700000000,
10700000000,
10600000000,
10500000000,
]

y=[
0.0185,
0.005,
0.0411,
0.36,
0.29,
0.2,
0.234,
0.59,
0.73,
0.8,
0.719,
0.709,
0.49,
0.604,
0.542,
0.49,
0.27,
1.03,
1.63,
1.2,
0.626,
1.29,
1.32,
1.29,
1.2,
1.14,
1.48,
2.21,
2.24,
2.2,
1.47,
]




x1=np.linspace(10**10,4*10**11)
y1=np.power(x1,5)/np.exp((np.multiply(x1,7.3*10**-15))+1)*10**-75

#plt.plot(x,y,'o')
plt.plot(x1,y1,'*')
y1
#plt.ylim(0,0.002)
#plt.xlim(0,10**12)
# Out:
# array([  5.40743303e-26,   1.01018026e-24,   6.32381108e-24,
#          2.41254537e-23,   6.92913657e-23,   1.65513611e-22,
#          3.47369374e-22,   6.62389552e-22,   1.17312663e-21,
#          1.95922180e-21,   3.11947146e-21,   4.77389283e-21,
#          7.06578899e-21,   1.01638132e-20,   1.42640322e-20,
#          1.95919894e-20,   2.64047668e-20,   3.49930462e-20,
#          4.56831701e-20,   5.88392016e-20,   7.48649836e-20,
#          9.42061974e-20,   1.17352420e-19,   1.44839182e-19,
#          1.77250023e-19,   2.15218548e-19,   2.59430483e-19,
#          3.10625725e-19,   3.69600403e-19,   4.37208923e-19,
#          5.14366026e-19,   6.02048834e-19,   7.01298905e-19,
#          8.13224282e-19,   9.39001540e-19,   1.07987784e-18,
#          1.23717296e-18,   1.41228137e-18,   1.60667425e-18,
#          1.82190156e-18,   2.05959408e-18,   2.32146541e-18,
#          2.60931409e-18,   2.92502559e-18,   3.27057437e-18,
# ...

# %%
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
# %matplotlib inline

x=[
36800000000,
36800000000,
32000000000,
31400000000,
31400000000,
22500000000,
22500000000,
22500000000,
22500000000,
22500000000,
22200000000,
22200000000,
22200000000,
15300000000,
15100000000,
15000000000,
15000000000,
15000000000,
15000000000,
15000000000,
15000000000,
15000000000,
11200000000,
10700000000,
10700000000,
10600000000,
10500000000,
8480000000,
8480000000,
8480000000,
8480000000,
8460000000,
8430000000,
8400000000,
8400000000,
8300000000,
8100000000,
8090000000,
8090000000,
8090000000,
8080000000,
8080000000,
8080000000,
5000000000,
5000000000,
5000000000,
353000000000,
231000000000,
150000000000
]

y=[
0.29,
0.2,
0.234,
0.59,
0.73,
0.8,
0.719,
0.709,
0.49,
0.604,
0.542,
0.49,
0.27,
1.03,
1.63,
1.2,
0.626,
1.29,
1.32,
1.29,
1.2,
1.14,
1.48,
2.21,
2.24,
2.2,
1.47,
1.94,
1.97,
1.94,
1.97,
2.05,
1.95,
2.07,
1.94,
1.93,
2.15,
1.99,
2.01,
2.02,
2.65,
2.11,
2.8,
2.61,
2.66,
2.4,
0.0185,
0.005,
0.0411
]

#3 τελευταίες τιμές στα x,y



plt.loglog(x,y,'o')

x1=np.linspace(5*10**9,7*10**11)
y1=1512508736828.07*np.power(x1,-1.196421306)

plt.loglog(x1,y1,'-',label='f(v)=1.51*10^12*v^(-1.20)')
plt.xlabel('logv (Hz)')
plt.ylabel('logf (Jy)')
plt.title('Synchrotron radiation')
plt.legend()
plt.savefig("Synchr_PL.png")

# %%
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
# %matplotlib inline

x=[
3000000000000,
2700000000000,
353000000000,
231000000000,
150000000000
]

y=[
0.938,
1.87,
0.0185,
0.005,
0.0411
]

plt.loglog(x,y,'o')
plt.xlabel('logv (Hz)')
plt.ylabel('logf (Jy)')

# %%
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
# %matplotlib inline








x1=[
3000000000000, 
2700000000000,
353000000000,
231000000000,
150000000000
]

y1=[0.938,1.8, 0.0185,0.005,0.0411]

x=[
36800000000,
36800000000,
32000000000,
31400000000,
31400000000,
22500000000,
22500000000,
22500000000,
22500000000,
22500000000,
22200000000,
22200000000,
22200000000,
15300000000,
15100000000,
15000000000,
15000000000,
15000000000,
15000000000,
15000000000,
15000000000,
15000000000,
11200000000,
10700000000,
10700000000,
10600000000,
10500000000,
8480000000,
8480000000,
8480000000,
8480000000,
8460000000,
8430000000,
8400000000,
8400000000,
8300000000,
8100000000,
8090000000,
8090000000,
8090000000,
8080000000,
8080000000,
8080000000,
5000000000,
5000000000,
5000000000
]

y=[
0.29,
0.2,
0.234,
0.59,
0.73,
0.8,
0.719,
0.709,
0.49,
0.604,
0.542,
0.49,
0.27,
1.03,
1.63,
1.2,
0.626,
1.29,
1.32,
1.29,
1.2,
1.14,
1.48,
2.21,
2.24,
2.2,
1.47,
1.94,
1.97,
1.94,
1.97,
2.05,
1.95,
2.07,
1.94,
1.93,
2.15,
1.99,
2.01,
2.02,
2.65,
2.11,
2.8,
2.61,
2.66,
2.4
]

plt.loglog(x,y,'o')
plt.loglog(x1,y1,'*r')
plt.savefig('S_dust.png')

# %%
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
# %matplotlib inline

x=[
3000000000000,
2700000000000,
353000000000,
231000000000,
150000000000
]

y=[
0.938,
1.87,
0.0185,
0.005,
0.0411
]

plt.plot(x,y,'o')
plt.xlabel('v (Hz)')
plt.ylabel('f (Jy)')
#plt.xlim(0,3.5*10**12)
plt.ylim(0,2)
x1=np.linspace(10**11,4*10**12)
y1=10**-50*x1**4.05
plt.plot(x1,y1,'*r')
plt.savefig('Dust-fit.png')

#Στο όριο R-J θα είναι νόμος δύναμης της μορφής const*v^2*v^β ή ν^(2+β), άρα β=2.05

# %%
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
# %matplotlib inline

x=[
36800000000,
36800000000,
32000000000,
31400000000,
31400000000,
22500000000,
22500000000,
22500000000,
22500000000,
22500000000,
22200000000,
22200000000,
22200000000,
15300000000,
15100000000,
15000000000,
15000000000,
15000000000,
15000000000,
15000000000,
15000000000,
15000000000,
11200000000,
10700000000,
10700000000,
10600000000,
10500000000,
8480000000,
8480000000,
8480000000,
8480000000,
8460000000,
8430000000,
8400000000,
8400000000,
8300000000,
8100000000,
8090000000,
8090000000,
8090000000,
8080000000,
8080000000,
8080000000,
5000000000,
5000000000,
5000000000,
353000000000,
231000000000,
150000000000
]

y=[
0.29,
0.2,
0.234,
0.59,
0.73,
0.8,
0.719,
0.709,
0.49,
0.604,
0.542,
0.49,
0.27,
1.03,
1.63,
1.2,
0.626,
1.29,
1.32,
1.29,
1.2,
1.14,
1.48,
2.21,
2.24,
2.2,
1.47,
1.94,
1.97,
1.94,
1.97,
2.05,
1.95,
2.07,
1.94,
1.93,
2.15,
1.99,
2.01,
2.02,
2.65,
2.11,
2.8,
2.61,
2.66,
2.4,
0.0185,
0.005,
0.0411
]

#3 τελευταίες τιμές στα x,y



plt.plot(x,y,'o')

x1=np.linspace(5*10**9,7*10**11)
y1=1512508736828.07*np.power(x1,-1.196421306)

plt.plot(x1,y1,'-',label='f(v)=1.51*10^12*v^(-1.20)')
plt.xlabel('v (Hz)')
plt.ylabel('f (Jy)')
plt.title('Synchrotron radiation')
plt.legend()
plt.savefig("Synchr_PL_notlog.png")

# %%
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
# %matplotlib inline

x=[
3000000000000,
2700000000000,
353000000000,
231000000000,
#150000000000
]

y=[
0.938,
1.87,
0.0185,
0.005,
#0.0411
]

plt.loglog(x,y,'o')
plt.xlabel('logv (Hz)')
plt.ylabel('logf (Jy)')
#plt.xlim(0,3.5*10**12)
plt.ylim(0,2)
x1=np.linspace(10**11,4*10**12)
y1=7.7*10**-30*x1**2.365
plt.loglog(x1,y1,'*r')
plt.savefig('Dust-fit_excel.png')

#Στο όριο R-J θα είναι νόμος δύναμης της μορφής const*v^2*v^β ή ν^(2+β), άρα β=0.365

# %%
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
# %matplotlib inline

x=[
3000000000000,
2700000000000,
353000000000,
231000000000,
#150000000000
]

y=[
0.938,
1.87,
0.0185,
0.005,
#0.0411
]

plt.loglog(x,y,'o')
plt.xlabel('logv (Hz)')
plt.ylabel('logf (Jy)')
#plt.xlim(0,3.5*10**12)
#plt.ylim(0,2)
x1=np.linspace(10**11,4*10**12)
y1=4.35*10**-38*x1**3.09
plt.loglog(x1,y1,'-r',label='f(v)=4.35*10^-38*v^(3.1)')
plt.legend()
plt.title('Modified black body dust fit')
plt.savefig('Dust-fit_excel_2.png')

#Στο όριο R-J θα είναι νόμος δύναμης της μορφής const*v^2*v^β ή ν^(2+β), άρα β=1.1
